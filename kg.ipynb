# %% [markdown]
# ## Problem statement
#
# T0 -
#
# 1. Zero involvment with any stakeholder - estimate who is the best person to contact for starters
# 2. One point of contact - usually champion
#
# def find_best_person(graph):
#     """
#     Use graph information, signals to find the best person to contact first.
#     Usually would return champion
#     """
#
# def find_all_consensus_nodes(graph):
#     """
#     Use graph information, signals to find all consensus nodes
#     Returns a list of nodes to traverse
#     """
#
# def best_path_to_decision_maker(start_node, graph):
#     """
#     Use graph information, signals to find the best path to decision maker
#     Returns a list of nodes to traverse
#     """
#
#
#
# When? When is the best time to approach the person?
#
# Who? Who all I should target next to get the deal consensus?
#
# What? What is the best way to approach the person?

# %%
import pickle


all_graphs = pickle.load(open("all_graphs.pkl", "rb"))
all_graphs
